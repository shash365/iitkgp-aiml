# %% [markdown]
# <a href="https://colab.research.google.com/github/shash365/iitkgp-aiml/blob/main/SupervisedLearning_DecisionTree_RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# Let's download the iris dataset from its weblink as follows:

# %%
path = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# %% [markdown]
# Now, assign the column names to the dataset as follows:

# %%
headernames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']

# %% [markdown]
# We have to read the dataset using the Pandas data frame as follows:

# %%
data = pd.read_csv(path, names=headernames)

# %%
data.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 5)

# %% [markdown]
# Now add the basic data preprocessing step.

# %%
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %% [markdown]
# Divide data in training and testing data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.3, random_state=0)

# %%
# Do Data Scaling

# %%
# This step is OPTIONAL in Decision Tree (DT), no need of Scaling data in DT. Scaling is imp in other classifiers
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(X_train)
X_train = ss.transform(X_train)
X_test = ss.transform(X_test)

# %% [markdown]
# Now we will use Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Finding the label prediction
y_pred = classifier.predict(X_train)

# %%
# Find accuracy score on Train data
accuracy_score(y_train, y_pred)
# Out:
# 1.0

# %% [markdown]
# Getting 100% accuracy with training data. Lets try with test data

# %%
y_pred = classifier.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9777777777777777

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       1.00      0.94      0.97        18
#  Iris-virginica       0.92      1.00      0.96        11
#
#        accuracy                           0.98        45
#       macro avg       0.97      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# # Random Forest

# %% [markdown]
# Now, let us try to improve the accuracy by training the model with the help of the RandomForestClassifier class of sklearn as follows, where the performances of 10 decision trees are combined:

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10)
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
y_pred = classifier.predict(X_train)

# %%
accuracy_score(y_train, y_pred)
# Out:
# 1.0

# %%
# Now with test data

# %%
y_pred = classifier.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9777777777777777

# %%
# We got 97.8% accuracywith RandomForest.

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       1.00      0.94      0.97        18
#  Iris-virginica       0.92      1.00      0.96        11
#
#        accuracy                           0.98        45
#       macro avg       0.97      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45

# %%
# We can calculate the accuracy score for more number of estimators (DTs) and see if accuracy
